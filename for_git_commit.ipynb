# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# %cd '/content/drive/MyDrive/AI'
# Out:
# /content/drive/MyDrive/AI

# %%
# git 생성
# !git init
# !git branch -M main
# !git config --global user.email 'aeea0520@gmail.com'
# !git config --global user.name 'aeeazip'
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/AI/.git/

# %%
# !git config pull.rebase false

# %%
# git commit
# !git add .
# !git commit -m "1,2 주차 실습 과제"
# Out:
# [main 9ac84fa] 1,2 주차 실습 과제
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# github 연동
# !git remote add origin https://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@github.com/aeeazip/AI.git

# %%
# !git remote rm origin

# %%
# git push
# !git pull origin main --allow-unrelated-histories
# !git push origin main
# Out:
# From https://github.com/aeeazip/AI
#  * branch            main       -> FETCH_HEAD
# hint: Waiting for your editor to close the file... 7[>4;2m="/content/drive/MyDrive/AI/.git/MERGE_MSG" 6L, 279B▽  Pzz\[0%m           [>cMerge branch 'main' of https://github.com/aeeazip/AI
# # Please enter a commit message to explain why this merge is necessary,# especially if it merges an updated upstream into a topic branch.#
# # Lines starting with '#' will be ignored, and an empty message aborts
# # the commit.
# ...
