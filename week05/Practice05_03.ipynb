# %%
import numpy as np

# 학습데이터 (입력이 2개 / 출력이 1개)
x_data = [[1.0, 2.0], [2.0, 2.0], [3.0, 3.0], [4.0, 3.0], [5.0, 3.0], [6.0, 2.0]]
y_data = [[0.0],      [0.0],      [0.0],      [1.0],      [1.0],      [1.0]] # 마지막 데이터를 1.0 -> 0.0 으로 변경 후 예측값이 작아진다.

x = np.array(x_data)
y = np.array(y_data)

# 라이브러리
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 딥러닝 구조 생성 (activation으로 예측 함수 지정 가능)
model = Sequential()
model.add(Dense(24, input_dim=2, activation='relu'))
#model.add(Dense(10, activation='relu')) # 주석 해제 : Dense가 10인 레이어를 추가함으로써 모델의 복잡성이 높아짐 + 더 다양한 데이터를 학습할 수 있기 때문에 더 높은 정확도와 더 낮은 손실을 갖게 된다.
model.add(Dense(1, activation='sigmoid'))

# 딥러닝 실행
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x, y, epochs=200, batch_size=6) # 모델 학습 : 학습 데이터는 x, y

# 결과 출력
result = model.evaluate(x, y) # 모델 평가 : 정확도와 손실 평가
print("\n<Model Evaluation>")
print("Accuracy: %.4f" % (result[1]))
print("Error: %.4f" % (result[0]))

print("\n<Expectation Test>")
output = model.predict(x)
print(output)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 605ms/step - loss: 0.5884 - accuracy: 0.5000
# Epoch 2/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5832 - accuracy: 0.5000
# Epoch 3/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5782 - accuracy: 0.5000
# Epoch 4/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5733 - accuracy: 0.5000
# Epoch 5/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5685 - accuracy: 0.5000
# Epoch 6/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5639 - accuracy: 0.5000
# Epoch 7/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5595 - accuracy: 0.5000
# Epoch 8/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5551 - accuracy: 0.5000
# Epoch 9/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5509 - accuracy: 0.5000
# Epoch 10/200
# ...
